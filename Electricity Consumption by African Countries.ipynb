# %% [markdown]
# # Electricity Consumption In 13 African Countries Against China And India
#
# # Exploratory Data Analysis and Future Predictions
#
# # Data Source - www.kaggle.com
#
# # Machine Learning Model Used - Logistic Regression
#
# # Predictions Were Made for 2021, 2022, 2023, 2024, 2025

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
electric = pd.read_csv("D:\DATA SCIENCE\ANALYSIS\World_Per_Capita_Electricity_Consumption.csv")

# %%
electric.head()
# Out:
#         Entity  Year  Per capita electricity (kWh)
# 0  Afghanistan  2000                        22.474
# 1  Afghanistan  2001                        27.399
# 2  Afghanistan  2002                        30.397
# 3  Afghanistan  2003                        39.652
# 4  Afghanistan  2004                        36.155

# %%
electric.tail()
# Out:
#         Entity  Year  Per capita electricity (kWh)
# 5615  Zimbabwe  2015                       679.553
# 5616  Zimbabwe  2016                       486.509
# 5617  Zimbabwe  2017                       513.434
# 5618  Zimbabwe  2018                       632.533
# 5619  Zimbabwe  2019                       617.672

# %%
electric.shape
# Out:
# (5620, 3)

# %%
electric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5620 entries, 0 to 5619
# Data columns (total 3 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Entity                        5620 non-null   object
#  1   Year                          5620 non-null   int64
#  2   Per capita electricity (kWh)  5620 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 131.8+ KB

# %%
electric.describe()
# Out:
#               Year  Per capita electricity (kWh)
# count  5620.000000                   5620.000000
# mean   2005.826157                   4095.887211
# std       9.238193                   5403.908499
# min    1985.000000                      0.000000
# 25%    2000.000000                    646.116250
# 50%    2007.000000                   2555.821500
# 75%    2013.000000                   5561.172750
# max    2021.000000                  58863.361000

# %%
electric.isnull().sum()
# Out:
# Entity                          0
# Year                            0
# Per capita electricity (kWh)    0
# dtype: int64

# %%
electric['Entity'].unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'American Samoa',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands', 'Brunei',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Cape Verde', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Chile', 'China', 'Colombia',
#        'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', 'Croatia',
#        'Cuba', 'Cyprus', 'Czechia', 'Democratic Republic of Congo',
#        'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador',
#        'Egypt', 'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Ethiopia', 'Europe', 'European Union (27)', 'Falkland Islands',
# ...

# %%
len(electric['Entity'].unique())
# Out:
# 213

# %%
electric['Entity'].value_counts()
# Out:
# Latvia                  37
# Bulgaria                37
# Cyprus                  37
# Czechia                 37
# Denmark                 37
#                         ..
# Haiti                   20
# Honduras                20
# Jamaica                 20
# Jordan                  20
# Netherlands Antilles    18
# Name: Entity, Length: 213, dtype: int64

# %%
nigeria_electricity_consumption = electric[electric['Entity']=='Nigeria']

# %%
nigeria_electricity_consumption.head()
# Out:
#        Entity  Year  Per capita electricity (kWh)
# 3568  Nigeria  2000                       115.665
# 3569  Nigeria  2001                       118.379
# 3570  Nigeria  2002                       160.783
# 3571  Nigeria  2003                       146.762
# 3572  Nigeria  2004                       171.718

# %%
nigeria_electricity_consumption.tail()
# Out:
#        Entity  Year  Per capita electricity (kWh)
# 3584  Nigeria  2016                       172.123
# 3585  Nigeria  2017                       171.812
# 3586  Nigeria  2018                       175.895
# 3587  Nigeria  2019                       177.491
# 3588  Nigeria  2020                       184.431

# %%
plt.figure(figsize = (15,7))
sns.barplot(x = 'Year',
            y = 'Per capita electricity (kWh)',
            hue = 'Entity',
            data = nigeria_electricity_consumption)
plt.xticks(rotation = 0)
plt.title("Nigeria Electricity Consumption")
plt.show()

# %%
plt.figure(figsize = (15,7))
plt.plot(electric['Year'][electric['Entity']=='Nigeria'],
electric['Per capita electricity (kWh)'][electric['Entity']=="Nigeria"])
plt.title("Nigeria Electricity Consumption")
plt.show()

# %%
ghana_electricity_consumption = electric[electric['Entity']=='Ghana']

# %%
ghana_electricity_consumption.head()
# Out:
#      Entity  Year  Per capita electricity (kWh)
# 1923  Ghana  2000                       370.054
# 1924  Ghana  2001                       391.404
# 1925  Ghana  2002                       351.049
# 1926  Ghana  2003                       275.943
# 1927  Ghana  2004                       276.339

# %%
plt.figure(figsize = (15,7))
sns.barplot(x = 'Year',
            y = 'Per capita electricity (kWh)',
            hue = 'Entity',
            data = ghana_electricity_consumption)
plt.xticks(rotation = 90)
plt.title("Ghana Electricity Consumption")
plt.show()

# %%
plt.figure(figsize = (15,7))
plt.plot(electric['Year'][electric['Entity']=='Ghana'],
electric['Per capita electricity (kWh)'][electric['Entity']=="Ghana"])
plt.title("Ghana Electricity Consumption")
plt.show()

# %%
togo_electricity_consumption = electric[electric['Entity']=='Togo']

# %%
togo_electricity_consumption.head()
# Out:
#      Entity  Year  Per capita electricity (kWh)
# 4985   Togo  2000                        34.522
# 4986   Togo  2001                        23.703
# 4987   Togo  2002                        28.478
# 4988   Togo  2003                        32.642
# 4989   Togo  2004                        33.085

# %%
plt.figure(figsize = (15,7))
sns.barplot(x = 'Year',
            y = 'Per capita electricity (kWh)',
            hue = 'Entity',
            data = togo_electricity_consumption)
plt.xticks(rotation = 90)
plt.title("Togo Electricity Consumption")
plt.show()

# %%
plt.figure(figsize = (15,7))
plt.plot(electric['Year'][electric['Entity']=='Togo'],
electric['Per capita electricity (kWh)'][electric['Entity']=="Togo"])
plt.title("Nigeria Electricity Consumption")
plt.show()

# %%
cameroon_electricity_consumption = electric[electric['Entity']=='Cameroon']

# %%
cameroon_electricity_consumption.head()
# Out:
#        Entity  Year  Per capita electricity (kWh)
# 850  Cameroon  2000                       221.976
# 851  Cameroon  2001                       219.851
# 852  Cameroon  2002                       199.352
# 853  Cameroon  2003                       216.634
# 854  Cameroon  2004                       235.212

# %%
plt.figure(figsize = (15,7))
sns.barplot(x = 'Year',
            y = 'Per capita electricity (kWh)',
            hue = 'Entity',
            data = cameroon_electricity_consumption)
plt.xticks(rotation = 90)
plt.title("Cameroon Electricity Consumption")
plt.show()

# %%
plt.figure(figsize = (15,7))
plt.plot(electric['Year'][electric['Entity']=='Cameroon'],
electric['Per capita electricity (kWh)'][electric['Entity']=="Cameroon"])
plt.title("Cameroon Electricity Consumption")
plt.show()

# %%
congo_electricity_consumption = electric[electric['Entity']=='Democratic Republic of Congo']

# %%
congo_electricity_consumption.head()
# Out:
#                             Entity  Year  Per capita electricity (kWh)
# 1301  Democratic Republic of Congo  2000                       126.138
# 1302  Democratic Republic of Congo  2001                       122.215
# 1303  Democratic Republic of Congo  2002                       121.442
# 1304  Democratic Republic of Congo  2003                       118.707
# 1305  Democratic Republic of Congo  2004                       132.178

# %%
plt.figure(figsize = (15,7))
sns.barplot(x = 'Year',
            y = 'Per capita electricity (kWh)',
            hue = 'Entity',
            data = congo_electricity_consumption)
plt.xticks(rotation = 90)
plt.title("Democratic Republic of Congo Electricity Consumption")
plt.show()

# %%
plt.figure(figsize = (15,7))
plt.plot(electric['Year'][electric['Entity']=='Democratic Republic of Congo'],
electric['Per capita electricity (kWh)'][electric['Entity']=="Democratic Republic of Congo"])
plt.title("Democratic Republic of Congo Electricity Consumption")
plt.show()

# %%
egypt_electricity_consumption = electric[electric['Entity']=='Egypt']

# %%
egypt_electricity_consumption.head()
# Out:
#      Entity  Year  Per capita electricity (kWh)
# 1453  Egypt  1985                       614.175
# 1454  Egypt  1986                       641.492
# 1455  Egypt  1987                       685.773
# 1456  Egypt  1988                       724.963
# 1457  Egypt  1989                       741.294

# %%
plt.figure(figsize = (15,7))
sns.barplot(x = 'Year',
            y = 'Per capita electricity (kWh)',
            hue = 'Entity',
            data = egypt_electricity_consumption)
plt.xticks(rotation = 90)
plt.title("Egypt Electricity Consumption")
plt.show()

# %%
plt.figure(figsize = (15,7))
plt.plot(electric['Year'][electric['Entity']=='Egypt'],
electric['Per capita electricity (kWh)'][electric['Entity']=="Egypt"])
plt.title("Egypt Electricity Consumption")
plt.show()

# %%
kenya_electricity_consumption = electric[electric['Entity']=='Kenya']

# %%
kenya_electricity_consumption.head()
# Out:
#      Entity  Year  Per capita electricity (kWh)
# 2670  Kenya  2000                       126.814
# 2671  Kenya  2001                       139.809
# 2672  Kenya  2002                       140.781
# 2673  Kenya  2003                       147.006
# 2674  Kenya  2004                       153.034

# %%
plt.figure(figsize = (15,7))
sns.barplot(x = 'Year',
            y = 'Per capita electricity (kWh)',
            hue = 'Entity',
            data = kenya_electricity_consumption)
plt.xticks(rotation = 90)
plt.title("Kenya Electricity Consumption")
plt.show()

# %%
plt.figure(figsize = (15,7))
plt.plot(electric['Year'][electric['Entity']=='Kenya'],
electric['Per capita electricity (kWh)'][electric['Entity']=="Kenya"])
plt.title("Kenya Electricity Consumption")
plt.show()

# %%
southafrica_electricity_consumption = electric[electric['Entity']=='South Africa']

# %%
southafrica_electricity_consumption.head()
# Out:
#             Entity  Year  Per capita electricity (kWh)
# 4575  South Africa  1985                      4390.940
# 4576  South Africa  1986                      4425.639
# 4577  South Africa  1987                      4442.656
# 4578  South Africa  1988                      4505.325
# 4579  South Africa  1989                      4546.584

# %%
plt.figure(figsize = (15,7))
sns.barplot(x = 'Year',
            y = 'Per capita electricity (kWh)',
            hue = 'Entity',
            data = southafrica_electricity_consumption)
plt.xticks(rotation = 90)
plt.title("South Africa Electricity Consumption")
plt.show()

# %%
plt.figure(figsize = (15,7))
plt.plot(electric['Year'][electric['Entity']=='South Africa'],
electric['Per capita electricity (kWh)'][electric['Entity']=="South Africa"])
plt.title("South Africa Electricity Consumption")
plt.show()

# %%
liberia_electricity_consumption = electric[electric['Entity']=='Liberia']

# %%
liberia_electricity_consumption.head()
# Out:
#        Entity  Year  Per capita electricity (kWh)
# 2862  Liberia  2000                        70.214
# 2863  Liberia  2001                        67.706
# 2864  Liberia  2002                        66.122
# 2865  Liberia  2003                        64.997
# 2866  Liberia  2004                        63.783

# %%
plt.figure(figsize = (15,7))
sns.barplot(x = 'Year',
            y = 'Per capita electricity (kWh)',
            hue = 'Entity',
            data = liberia_electricity_consumption)
plt.xticks(rotation = 90)
plt.title("Liberia Electricity Consumption")
plt.show()

# %%
plt.figure(figsize = (15,7))
plt.plot(electric['Year'][electric['Entity']=='Liberia'],
electric['Per capita electricity (kWh)'][electric['Entity']=="Liberia"])
plt.title("Liberia Electricity Consumption")
plt.show()

# %%
malawi_electricity_consumption = electric[electric['Entity']=='Malawi']

# %%
malawi_electricity_consumption.head()
# Out:
#       Entity  Year  Per capita electricity (kWh)
# 2996  Malawi  2000                       111.313
# 2997  Malawi  2001                       111.004
# 2998  Malawi  2002                       113.713
# 2999  Malawi  2003                       112.582
# 3000  Malawi  2004                       121.039

# %%
plt.figure(figsize = (15,7))
sns.barplot(x = 'Year',
            y = 'Per capita electricity (kWh)',
            hue = 'Entity',
            data = malawi_electricity_consumption)
plt.xticks(rotation = 90)
plt.title("Malawi Electricity Consumption")
plt.show()

# %%
plt.figure(figsize = (15,7))
plt.plot(electric['Year'][electric['Entity']=='Malawi'],
electric['Per capita electricity (kWh)'][electric['Entity']=="Malawi"])
plt.title("Malawi Electricity Consumption")
plt.show()

# %%
morocco_electricity_consumption = electric[electric['Entity']=='Morocco']

# %%
morocco_electricity_consumption.head()
# Out:
#        Entity  Year  Per capita electricity (kWh)
# 3282  Morocco  1985                       326.457
# 3283  Morocco  1986                       337.854
# 3284  Morocco  1987                       341.234
# 3285  Morocco  1988                       375.843
# 3286  Morocco  1989                       370.510

# %%
plt.figure(figsize = (15,7))
sns.barplot(x = 'Year',
            y = 'Per capita electricity (kWh)',
            hue = 'Entity',
            data = morocco_electricity_consumption)
plt.xticks(rotation = 90)
plt.title("Morocco Electricity Consumption")
plt.show()

# %%
plt.figure(figsize = (15,7))
plt.plot(electric['Year'][electric['Entity']=='Morocco'],
electric['Per capita electricity (kWh)'][electric['Entity']=="Morocco"])
plt.title("Morocco Electricity Consumption")
plt.show()

# %%
rwanda_electricity_consumption = electric[electric['Entity']=='Rwanda']

# %%
rwanda_electricity_consumption.head()
# Out:
#       Entity  Year  Per capita electricity (kWh)
# 4143  Rwanda  2000                        13.991
# 4144  Rwanda  2001                        10.813
# 4145  Rwanda  2002                        11.629
# 4146  Rwanda  2003                        13.673
# 4147  Rwanda  2004                         9.677

# %%
plt.figure(figsize = (15,7))
sns.barplot(x = 'Year',
            y = 'Per capita electricity (kWh)',
            hue = 'Entity',
            data = rwanda_electricity_consumption)
plt.xticks(rotation = 90)
plt.title("Rwanda Electricity Consumption")
plt.show()

# %%
plt.figure(figsize = (15,7))
plt.plot(electric['Year'][electric['Entity']=='Rwanda'],
electric['Per capita electricity (kWh)'][electric['Entity']=="Rwanda"])
plt.title("Rwanda Electricity Consumption")
plt.show()

# %%
senegal_electricity_consumption = electric[electric['Entity']=='Senegal']

# %%
senegal_electricity_consumption.head()
# Out:
#        Entity  Year  Per capita electricity (kWh)
# 4338  Senegal  2000                       146.973
# 4339  Senegal  2001                       168.292
# 4340  Senegal  2002                       174.451
# 4341  Senegal  2003                       180.620
# 4342  Senegal  2004                       184.550

# %%
plt.figure(figsize = (15,7))
sns.barplot(x = 'Year',
            y = 'Per capita electricity (kWh)',
            hue = 'Entity',
            data = senegal_electricity_consumption)
plt.xticks(rotation = 90)
plt.title("Senegal Electricity Consumption")
plt.show()

# %%
plt.figure(figsize = (15,7))
plt.plot(electric['Year'][electric['Entity']=='Senegal'],
electric['Per capita electricity (kWh)'][electric['Entity']=="Senegal"])
plt.title("Senegal Electricity Consumption")
plt.show()

# %%
china_electricity_consumption = electric[electric['Entity']=='China']

# %%
china_electricity_consumption.head()
# Out:
#      Entity  Year  Per capita electricity (kWh)
# 1022  China  1985                       381.828
# 1023  China  1986                       410.524
# 1024  China  1987                       445.542
# 1025  China  1988                       479.211
# 1026  China  1989                       504.861

# %%
plt.figure(figsize = (15,7))
sns.barplot(x = 'Year',
            y = 'Per capita electricity (kWh)',
            hue = 'Entity',
            data = china_electricity_consumption)
plt.xticks(rotation = 90)
plt.title("China Electricity Consumption")
plt.show()

# %%
plt.figure(figsize = (15,7))
plt.plot(electric['Year'][electric['Entity']=='China'],
electric['Per capita electricity (kWh)'][electric['Entity']=="China"])
plt.title("China Electricity Consumption")
plt.show()

# %%
india_electricity_consumption = electric[electric['Entity']=='India']

# %%
india_electricity_consumption.head()
# Out:
#      Entity  Year  Per capita electricity (kWh)
# 2307  India  1985                       237.628
# 2308  India  1986                       252.723
# 2309  India  1987                       272.873
# 2310  India  1988                       288.136
# 2311  India  1989                       318.526

# %%
plt.figure(figsize = (15,7))
sns.barplot(x = 'Year',
            y = 'Per capita electricity (kWh)',
            hue = 'Entity',
            data = india_electricity_consumption)
plt.xticks(rotation = 90)
plt.title("India Electricity Consumption")
plt.show()

# %%
plt.figure(figsize = (15,7))
plt.plot(electric['Year'][electric['Entity']=='India'],
electric['Per capita electricity (kWh)'][electric['Entity']=="India"])
plt.title("India Electricity Consumption")
plt.show()

# %%
x = nigeria_electricity_consumption.drop(['Per capita electricity (kWh)', 'Entity'], axis = 1)
y = nigeria_electricity_consumption['Per capita electricity (kWh)']

# %%
x.shape
# Out:
# (21, 1)

# %%
y.shape
# Out:
# (21,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
model_nigeria=LinearRegression()
model_nigeria.fit(x,y)
# Out:
# LinearRegression()

# %%
print("Coefficient: ",model_nigeria.coef_)
print("intercept: ",model_nigeria.intercept_)
pre = model_nigeria.predict(x)
# Out:
# Coefficient:  [2.28256753]
# intercept:  -4430.835645021645

# %%
plt.figure(figsize=(8,6))
plt.scatter(x,y,label='Acutal value')
plt.plot(x,pre,color='g',label='Predicted value')
plt.legend()
plt.title("Nigeria",color='r')
plt.xlabel("Years",color='r')
plt.ylabel("per capital electricity consumption(kWh)",color='r')
plt.tight_layout()
plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
years=[2021,2022,2023,2024,2025]
for i in years:
    print(model_nigeria.predict([[i]]))
# Out:
# [182.2333381]
# [184.51590563]
# [186.79847316]
# [189.08104069]
# [191.36360823]

# %%
from sklearn.metrics import mean_squared_error

# %%
print("By function: ",mean_squared_error(y,model_nigeria.predict(x)))
# Out:
# By function:  182.3555263713254
